# %%
# 1019 회의
# tenure 변수 구간 나눠서 해보기
# 은행, 카드사는 리뷰 데이터가 데이터에 포함된 경우도 많음
# 리뷰 텍스트 데이터나 상품설명 등의 비정형 데이터를 다룰 수 있는 인코딩 방식도 중요!
# 자세한 내용은 코랩 참고

# 과제 전형은 성능을 무작정 높이는 게 중점이 X, 적절한 것을 사용하는 것이 중요

# 연속형 변수 주요 스케일링 방식에서 Power Transformer가 표준화, 정규화보다 좋을 때도 있음
# 데이터 분포를 보니, 표준화/정규화보다 더 적합하다고 생각~ 등등 잘 정리하기

# 날짜 데이터에서 요일, 월, 분기를 따로 파생변수로 생성하면 성능 개선에 도움이 많이 됐었다!!

# 데이터 특성을 반영한 분할법도 있음!
# Group K-Fold(한 고객의 여러 거래 내역) 등등
# 시계열 데이터를 일부러 넣어서 시계열 분할을 사용할 수 있는지 보는 경우도 있었다!

# Optuna는 Grid search등 과의 차이점 보기
# Optuna부분 시각화도 참고하면 좋음!
# 성능지표는 회사의 상황에 따라 어떤 지표를 개선하는 것이 좋을지 생각해보고 활용하면 면접에서 굿
# trade-off 관계인 지표들이 있으니까!

# 모델 피팅 후, 모델 피쳐를 해석해서 어떻게 활용하고, 현업부서들과 커뮤니케이션 할 수 있을지 인사이트 내는게 제일 중요!!
# 모델링에서 끝나는게 아니라, 비즈니스 인사이트를 도출하는 것이 중요!

## Q&A
# 불균형 데이터를 oversampling 하는 것 말고도 다른 방법도 찾아보기
# 기술면접 주의사항(완벽하게 알지 못하는건 말하지 말기, 딥하게 꼬리질문이 들어오는 경우가 있음)
# 하이퍼파라미터 튜닝은 부가적인것...! feature나 EDA하면서 괜찮은 feature를 선택하는게 더 성능 개선에 좋다!!
# 데이터를 기반으로 성능 개선을 하는게 제일 좋다!!
# 과제전형에서 통계적 가설검정까지는 좀 투머치!
# input data가 좋아야 tuning 결과도 좋아짐...(특히 Hyperparameter tuning은 그렇다!)
